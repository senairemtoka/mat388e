# %% [markdown]
# # Sena İrem Toka 090190361

# %% [markdown]
# ### First of all I found the pitchfork reviews dataset but it only had the artist, album, genre, score, date, author, role, review, bnm, link, label, release year. But when I looked more and more I found that people had scraped data of these albums from Spotify giving some characteristics about the albums such as the danceability, energy, key, loudness, speechiness, acousticness, instrumentalness, liveness, valence and tempo. But this dataset didn't have the reviews. So I decided to merge these two and use that for my project, this made the dataset a little bit smaller but I think it will be more interesting this way.

# %% [markdown]
# I got the dataset with the reviews of Pitchfork from here:
#   -  https://components.one/datasets/pitchfork-reviews-dataset
#
# I got the dataset with the Spotify audio features from here:
#
#   -  https://zenodo.org/records/3603330#.XqXCSS3Mxjs

# %%
import pandas as pd
df1 = pd.read_csv('/Users/senairemtoka/Downloads/pitchfork.csv')

df1
# Out:
#                         artist                                       album  \
# 0                  David Byrne  “…The Best Live Show of All Time” — NME EP
# 1                    DJ Healer           Lost Lovesongs / Lostsongs Vol. 2
# 2                  Jorge Velez                                 Roman Birds
# 3                      Chandra                          Transportation EPs
# 4             The Chainsmokers                                    Sick Boy
# ...                        ...                                         ...
# 20868              The Pleased                           Don't Make Things
# 20869             Electric Six                                        Fire
# 20870      Anti-Pop Consortium                   Antipop Vs. Matthew Shipp
# 20871  Damon & Naomi, Kurihara                     Song to the Siren: Live
# 20872           Ben Folds Five                              Ben Folds Live
#
# ...

# %%
df1 = df1.rename(columns={'release_year': 'releaseyear'})
df1
# Out:
#                         artist                                       album  \
# 0                  David Byrne  “…The Best Live Show of All Time” — NME EP
# 1                    DJ Healer           Lost Lovesongs / Lostsongs Vol. 2
# 2                  Jorge Velez                                 Roman Birds
# 3                      Chandra                          Transportation EPs
# 4             The Chainsmokers                                    Sick Boy
# ...                        ...                                         ...
# 20868              The Pleased                           Don't Make Things
# 20869             Electric Six                                        Fire
# 20870      Anti-Pop Consortium                   Antipop Vs. Matthew Shipp
# 20871  Damon & Naomi, Kurihara                     Song to the Siren: Live
# 20872           Ben Folds Five                              Ben Folds Live
#
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20873 entries, 0 to 20872
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   artist        20872 non-null  object
#  1   album         20870 non-null  object
#  2   genre         18570 non-null  object
#  3   score         20873 non-null  float64
#  4   date          20873 non-null  object
#  5   author        20873 non-null  object
#  6   role          17377 non-null  object
#  7   review        20871 non-null  object
#  8   bnm           20873 non-null  int64
#  9   link          20873 non-null  object
#  10  label         20838 non-null  object
#  11  release_year  20463 non-null  float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 1.9+ MB

# %%
import pandas as pd
df2 = pd.read_csv('/Users/senairemtoka/Downloads/output-data.csv')

df2
# Out:
#                artist                              album        reviewauthor  \
# 0            Studio 1                           Studio 1      Andy Battaglia
# 1          John Fahey  The Great Santa Barbara Oil Slick     Mark Richardson
# 2      Reigning Sound                    Too Much Guitar  Stephen M. Deusner
# 3      The Red Thread                     After the Last        Chris Dahlen
# 4          Mac Miller                           Swimming      Evan Rytlewski
# ...               ...                                ...                 ...
# 18398       DJ Khaled                    Father of Asahd       Rawiya Kameir
# 18399        Interpol                     A Fine Mess EP       Brian Josephs
# 18400  Injury Reserve                     Injury Reserve      Sheldon Pearce
# 18401       Operators                       Radiant Dawn       Stuart Berman
# 18402        Slowthai        Nothing Great About Britain         Jazz Monroe
#
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18403 entries, 0 to 18402
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   artist            18402 non-null  object
#  1   album             18403 non-null  object
#  2   reviewauthor      18403 non-null  object
#  3   score             18403 non-null  float64
#  4   releaseyear       18078 non-null  float64
#  5   reviewdate        18403 non-null  object
#  6   recordlabel       18377 non-null  object
#  7   genre             17114 non-null  object
#  8   danceability      18403 non-null  float64
#  9   energy            18403 non-null  float64
#  10  key               18403 non-null  float64
#  11  loudness          18403 non-null  float64
#  12  speechiness       18403 non-null  float64
#  13  acousticness      18403 non-null  float64
#  14  instrumentalness  18403 non-null  float64
#  15  liveness          18403 non-null  float64
# ...

# %%
merged_df2 = pd.merge(df1, df2, on=['artist', 'album', 'genre', 'score', 'releaseyear'], how='inner')
merged_df2
# Out:
#                        artist                        album         genre  \
# 0                     Chandra           Transportation EPs          Rock
# 1            The Chainsmokers                     Sick Boy    Electronic
# 2              Silent Servant  Shadows of Death and Desire    Electronic
# 3      A Boogie Wit Da Hoodie                   Hoodie SZN           Rap
# 4                       Çaykh                  V I S C 0 9  Experimental
# ...                       ...                          ...           ...
# 14086          Arthur Russell                  Springfield  Experimental
# 14087                     Cex                Know Doubt EP    Electronic
# 14088            Jaga Jazzist                 What We Must          Jazz
# 14089                   Twine                        Twine    Electronic
# 14090          Ben Folds Five               Ben Folds Live          Rock
#
#        score              date             author           role  \
# ...

# %%
merged_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14091 entries, 0 to 14090
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   artist            14090 non-null  object
#  1   album             14091 non-null  object
#  2   genre             12818 non-null  object
#  3   score             14091 non-null  float64
#  4   date              14091 non-null  object
#  5   author            14091 non-null  object
#  6   role              11978 non-null  object
#  7   review            14090 non-null  object
#  8   bnm               14091 non-null  int64
#  9   link              14091 non-null  object
#  10  label             14069 non-null  object
#  11  releaseyear       13844 non-null  float64
#  12  reviewauthor      14091 non-null  object
#  13  reviewdate        14091 non-null  object
#  14  recordlabel       14069 non-null  object
#  15  danceability      14091 non-null  float64
# ...

# %% [markdown]
# The features of the dataset are:
#
# | Column Name       | Explanation                                                                                            |
# |-------------------|--------------------------------------------------------------------------------------------------------|
# | artist            | The name of the artist who released the album.                                                         |
# | album             | The title of the album.                                                                                |
# | genre             | The genre of the album.                                                                                |
# | score             | The score given to the album by the reviewer.                                                           |
# | date              | The date when the review was published.                                                                 |
# | author            | The author of the review.                                                                              |
# | role              | The role of the author (if available).                                                                  |
# | review            | The review text.                                                                                       |
# | bnm               | Indicates whether the album received the "Best New Music" designation (1 for yes, 0 for no).            |
# | link              | The link to the review.                                                                                |
# | label             | The record label associated with the album.                                                             |
# | releaseyear       | The release year of the album.                                                                         |
# | reviewauthor      | The author of the review (if available).                                                                |
# | reviewdate        | The date when the review was published.                                                                 |
# | recordlabel       | The record label associated with the album.                                                             |
# | danceability      | The danceability score of the album (if available).                                                     |
# | energy            | The energy score of the album (if available).                                                           |
# | key               | The key of the album (if available).                                                                    |
# | loudness          | The loudness score of the album (if available).                                                         |
# | speechiness       | The speechiness score of the album (if available).                                                      |
# | acousticness      | The acousticness score of the album (if available).                                                     |
# | instrumentalness  | The instrumentalness score of the album (if available).                                                 |
# | liveness          | The liveness score of the album (if available).                                                         |
# | valence           | The valence score of the album (if available).                                                          |
# | tempo             | The tempo of the album (if available).                                                                  |

# %% [markdown]
# ### Here are the descriptions and ranges for each audio feature, taken from  https://developer.spotify.com/documentation/web-api/reference/get-audio-features

# %% [markdown]
# | Feature          | Description                                                                                                                     | Range          |
# |------------------|---------------------------------------------------------------------------------------------------------------------------------|----------------|
# | Danceability     | Describes how suitable a track is for dancing based on a combination of musical elements including tempo, rhythm stability, beat strength, and overall regularity. | 0.0 to 1.0    |
# | Energy           | Represents a perceptual measure of intensity and activity. Typically, energetic tracks feel fast, loud, and noisy.             | 0.0 to 1.0    |
# | Key              | The key the track is in. Integers map to pitches using standard Pitch Class notation. E.g., 0 = C, 1 = C♯/D♭, 2 = D, and so on. | 0 to 11       |
# | Loudness         | The overall loudness of a track in decibels (dB). Loudness values are averaged across the entire track and are useful for comparing relative loudness of tracks. | -60.0 to 0.0 dB |
# | Mode             | Indicates the modality (major or minor) of a track, the type of scale from which its melodic content is derived.             | 0 or 1 (0 = Minor, 1 = Major) |
# | Speechiness      | Detects the presence of spoken words in a track. The more exclusively speech-like the recording (e.g., talk show, audio book, poetry), the closer to 1.0 the attribute value. | 0.0 to 1.0    |
# | Acousticness     | A confidence measure from 0.0 to 1.0 of whether the track is acoustic. 1.0 represents high confidence the track is acoustic. | 0.0 to 1.0    |
# | Instrumentalness | Predicts whether a track contains no vocals. The closer the instrumentalness value is to 1.0, the greater likelihood the track contains no vocal content. | 0.0 to 1.0    |
# | Liveness         | Detects the presence of an audience in the recording. Higher liveness values represent an increased probability that the track was performed live. | 0.0 to 1.0    |
# | Valence          | A measure from 0.0 to 1.0 describing the musical positiveness conveyed by a track. Tracks with high valence sound more positive (e.g., happy, cheerful, euphoric), while tracks with low valence sound more negative (e.g., sad, depressed, angry). | 0.0 to 1.0    |
# | Tempo            | The overall estimated tempo of a track in beats per minute (BPM). In musical terminology, tempo is the speed or pace of a given piece and derives directly from the average beat duration. | 0.0 to 200.0 BPM |

# %% [markdown]
# ## Hypothesis
#
# - There exists a relationship between the Spotify audio features of music albums and the reviews provided by Pitchfork, suggesting that certain characteristics of music contribute to its critical reception, and these relationships can be explored and quantified using data analysis and machine learning algorithms.

# %% [markdown]
# ## The questions I would like to ask the dataset and the methods I will use to answer the questions:

# %% [markdown]
# - What are the general trends and patterns in the dataset? What are the distributions of different features across different genres?
#
#     - Exploratory Data Analysis to visualize distributions, trends, and correlations.
#     - Analysis to examine trends in music preferences over time such as what genre got the highest scores overall each year.
#
#
# - Which features (e.g., tempo, danceability, energy) have the most significant impact on album reviews?
#
#     - Correlation analysis to identify relationships between features and review scores. Using Linear Regression models to identify the impact of the variables.
#
# - Using these features can we build a model to guess the scores that albums get?
#
#     - Regression techniques such as Ordinary Least Squares, Ridge Regression, Lasso Regression.
#     - Ensemble methods like Random Forest Regression or Gradient Boosting Regression.
#
# - Are there any unusual patterns or outliers in the dataset, such as albums that received unexpectedly high or low ratings? & Are there any albums that have similar audio features that get drastically different Pitchfork scores?
#
#     - Clustering algorithms such as K-means or Hierarchical Clustering. Using PCA and/or LDA to see the outliers.
#
#
# - Can we group albums into clusters based on their audio features and other attributes?
#
#     - Clustering methods like K-means, DBSCAN.
#     - Dimensionality reduction techniques like PCA or t-SNE for visualization.
#
# - What factors contribute most to the overall rating of an album?
#     - Examining the linear regression coefficients and F-scores.
#
# - Are there any trends in music preferences over time? How have genres evolved?
#
#      - Topic modeling techniques like Latent Dirichlet Allocation (LDA) for identifying evolving genres.
#
# - What is the sentiment of reviews towards certain albums, artists and genres?
#
#     - Natural Language Processing (NLP) techniques for sentiment analysis.
#
# - Can we predict the success of an album -whether it will get "Best New Music" distinction- based on its features and reviews?
#     - Binary classification algorithms like Logistic Regression and Support Vector Machines (SVM).
#
#
# - Can we predict the genre of a music album based on its audio features?
#     - Classification algorithms like Random Forest, k-Nearest Neighbors, or Support Vector Machines (SVM).
#
# - Can we identify groups of similar Pitchfork reviews based on their content?
#
#     - Clustering algorithms like K-means or Hierarchical Clustering.
#
# - How does ordinary least squares regression perform in predicting Pitchfork review scores using the audio features compared to regularized regression methods like lasso?
#
#     - Regression techniques like OLS, Ridge Regression, Lasso Regression.
#
#
# - Can we use decision tree regression to model the relationship between Spotify audio features and Pitchfork review scores?
#
#     - Decision Tree Regression and/or Random Forest Regression.
#
# - Is it possible to classify music tracks into different mood categories (e.g., happy, sad, energetic) based on their audio features?
#
#     - Multiclass classification algorithms like Random Forest, Decision Trees, or Neural Networks.
#
# - Do labels that the artists are signed have any affect on the scores they get? Do bigger label artists get better reviews?

# %% [markdown]
# ## The hardware and software that are going to be used:

# %% [markdown]
# 1. Hardware:
# - Macbook Pro 14-inch (2021)
# - 16 GB RAM
# - Processor: Apple M1 Pro Chip
# - 14-core GPU
# - 16-core Neural Engine
# - MacOS Sonoma
#
# 2. Software:
# - Python 3.11.7
# - Jupyter Notebook 6.5.4
#
# If necessary, I will use the ITU UHEM processors
